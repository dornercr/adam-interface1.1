# %%
import pandas as pd

# Dictionary containing CSV file paths grouped by language
csv_files = {
    "arabic": [
        "ILR_CSVs/arabic_news_articles_with_ilr_7_19_24_part1.csv",
        "ILR_CSVs/translated_arabic_news_07182024_part1.csv",
        "ILR_CSVs/translated_arabic_news_articles_with_ilr10012024_part1.csv",
        "ILR_CSVs/translated_arabic_news_articles_with_ilr10012024_part2.csv"
    ],
    "chinese": [
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part1.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part2.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part3.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part4.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part5.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part6.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part7.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part8.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part9.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part10.csv",
        "ILR_CSVs/chinese_news_articles_with_ilr20241119_part11.csv"
    ],
    "english": [
        "ILR_CSVs/english_news_articles_with_ilr7182024_part1.csv"
    ],
    "french": [
        "ILR_CSVs/french_news_articles_with_ilr10012024_part1.csv",
        "ILR_CSVs/french_news_articles_with_ilr10012024_part2.csv",
        "ILR_CSVs/french_news_articles_with_ilr10012024_part3.csv",
        "ILR_CSVs/french_news_articles_with_ilr10012024_part4.csv",
        "ILR_CSVs/french_news_articles_with_ilr10012024_part5.csv",
        "ILR_CSVs/french_news_articles_with_ilr10012024_part6.csv",
        "ILR_CSVs/french_news_articles_with_ilr10012024_part7.csv",
        "ILR_CSVs/translated_french_news7192024_part1.csv"
    ],
    "german": [
        "ILR_CSVs/german_articles_with_ilr09202024_part1.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part2.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part3.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part4.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part5.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part6.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part7.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part8.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part9.csv",
        "ILR_CSVs/german_articles_with_ilr09202024_part10.csv",
        "ILR_CSVs/translated_german_news09092024_part1.csv",
        "ILR_CSVs/translated_german_news_part1.csv"
    ],
    "russian": [
        "ILR_CSVs/russian_news_articles_with_ilr10012024_part1.csv",
        "ILR_CSVs/russian_news_articles_with_ilr10012024_part2.csv",
        "ILR_CSVs/russian_news_articles_with_ilr10012024_part3.csv",
        "ILR_CSVs/russian_news_articles_with_ilr10012024_part4.csv",
        "ILR_CSVs/russian_news_articles_with_ilr10012024_part5.csv",
        "ILR_CSVs/russian_news_articles_with_ilr10012024_part6.csv",
        "ILR_CSVs/russian_news_articles_with_ilr10012024_part7.csv"
    ],
    "spanish": [
        "ILR_CSVs/spanish_news_articles_with_ilr10012024_part1.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr10012024_part2.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr10012024_part3.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr10012024_part4.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr10012024_part5.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr10012024_part6.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr10012024_part7.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr7182024_part1.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr7182024_part2.csv",
        "ILR_CSVs/spanish_news_articles_with_ilr7192024_part1.csv",
        "ILR_CSVs/translated_spanish_news_07192024_part1.csv",
        "ILR_CSVs/translated_spanish_news_07192024_part2.csv",
        "ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part1.csv",
        "ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part2.csv",
        "ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part3.csv",
        "ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part4.csv",
        "ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part5.csv",
        "ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part6.csv",
        "ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part7.csv"
    ],
    "turkish": [
        "ILR_CSVs/turkish_news_part1_part1.csv",
        "ILR_CSVs/turkish_news_part1_part2.csv"
    ]
}

# Iterate over each language and its respective files
for language, files in csv_files.items():
    print(f"\n--- {language.upper()} ARTICLES ---\n")
    for file_path in files:
        try:
            # Load the CSV file into a DataFrame
            df = pd.read_csv(file_path)
            
            # Print the file name and the head of the DataFrame
            print(f"File: {file_path}")
            print(df.head())
            print("\n")
        except Exception as e:
            print(f"Error loading {file_path}: {e}\n")

# List to store results
data = []

# Iterate over each language and its respective files
for language, files in csv_files.items():
    for file_path in files:
        try:
            # Load the CSV file into a DataFrame
            df = pd.read_csv(file_path)
            
            # Collect the file name and the head of the DataFrame
            for _, row in df.head().iterrows():
                data.append({"language": language, "file": file_path, **row.to_dict()})
        except Exception as e:
            data.append({"language": language, "file": file_path, "error": str(e)})

# Save the results to a new CSV file
output_df = pd.DataFrame(data)
output_df.to_csv("aggregated_results.csv", index=False)

print("Results saved to aggregated_results.csv")
# Out:
# --- ARABIC ARTICLES ---
#
# File: ILR_CSVs/arabic_news_articles_with_ilr_7_19_24_part1.csv
#                                                title  \
# 0  موعد مباراة إيطاليا وسويسرا في ثمن نهائي يورو ...
# 1  موعد مباراة تركيا والنمسا في ثمن نهائي يورو 20...
# 2  موعد مباراة إيطاليا وكرواتيا في يورو 2024 والق...
# 3  موعد مباراة البرتغال ضد سلوفينيا في يورو 2024 ...
# 4  شركة Corsair تكشف عن كرسي TC500 LUXE E-Sports ...
#
#                                              summary  \
# 0  نستعرض في السطور التالية موعد مباراة إيطاليا ض...
# 1  تلعب تركيا مع النمسا في ثمن نهائي بطولة أمم أو...
# 2  في الجولة الأخيرة من دور المجموعات لكأس أمم أو...
# 3  نسلط الضوء في السطور التالية على موعد مباراة م...
# 4  هذا الموضوع شركة Corsair تكشف عن كرسي TC500 LU...
#
#                                                 text language  \
# 0  () ()\n2024 .\n 29 / .\n 19:00 .\n " " 2024 4 ...   Arabic
# 1  () ()\n14 / .\n " " 1- 3-1 3-2 .\nlist of 2 it...   Arabic
# 2  22:00 ()\n24/6/2024-| : 24/6/202403:22 ( )\n20...   Arabic
# 3  2024 ()\n30/6/2024-| : 30/6/202411:41 ( )\n( 2...   Arabic
# 4  Secretlab Razer . \n Corsair TC500 LUXE. \n 49...   Arabic
#
#                                                 link  ilr_quantized  \
# 0  https://www.aljazeera.net/sport/2024/6/26/uefa...            1.0
# 1  https://www.aljazeera.net/sport/2024/7/2/%d9%8...            1.0
# 2  https://www.aljazeera.net/sport/2024/6/24/%d9%...            1.5
# 3  https://www.aljazeera.net/sport/2024/6/30/port...            1.0
# 4  https://www.unlimit-tech.com/2024/07/%d8%b4%d8...            1.5
#
#                                   ilr_range  ilr_regressed
# 0   [0.7698419510133958, 1.383596748311007]       1.076719
# 1  [0.7091466710580703, 1.4847555482365495]       1.096951
# 2  [0.49195084708482306, 2.104829491749106]       1.298390
# 3  [0.8935815016702604, 1.1773641638828993]       1.035473
# 4  [0.7243837546721041, 1.9653697471967375]       1.344877
#
#
# File: ILR_CSVs/translated_arabic_news_07182024_part1.csv
#                                                title  \
# 0      5 مناطق الأكثر في السيارات والمراكز الإسعافية
# 1                    فندق لاستضافة النباتات المنزلية
# 2  ضمن التعاون بين وزارة المالية والبنك الدولي.. ...
# 3        السعودية ضمن أكبر 20 اقتصادا عالميا في 2024
# 4  الرياض تتصدر إصابات فاشيات الأمراض المنقولة با...
#
#                                              summary  \
# 0  23% الرياض514 مركزاالأقل مراكزسيارات ومراكزالأ...
# 1  لم تعد الفنادق مقتصرة على الإنسان أو الحيوان، ...
# 2  في إطار التعاون القائم بين وزارة المالية ومجمو...
# 3  الناتج المحلي الإجماليحلت السعودية في المرتبة ...
# 4  1891 مصاباإصابات الفئاتالأكثر فاشياتسجلت فاشيا...
#
#                                                 text language  \
# 0  23% الرياض\n\n514 مركزا\n\nالأقل مراكز\n\nسيار...   Arabic
# 1  لم تعد الفنادق مقتصرة على الإنسان أو الحيوان، ...   Arabic
# 2  في إطار التعاون القائم بين وزارة المالية ومجمو...   Arabic
# 3  الناتج المحلي الإجمالي\n\nحلت السعودية في المر...   Arabic
# 4  1891 مصابا\n\nإصابات الفئات\n\nالأكثر فاشيات\n...   Arabic
#
#                                          link  ilr_quantized     ilr_range  \
# 0  https://www.alwatan.com.sa/article/1150333           -1.0  [-1.0, -1.0]
# 1  https://www.alwatan.com.sa/article/1150352           -1.0  [-1.0, -1.0]
# 2  https://www.alwatan.com.sa/article/1150363           -1.0  [-1.0, -1.0]
# 3  https://www.alwatan.com.sa/article/1150345           -1.0  [-1.0, -1.0]
# 4  https://www.alwatan.com.sa/article/1150354           -1.0  [-1.0, -1.0]
#
#    ilr_regressed                                 translated_summary
# 0           -1.0  23% Riyadh 514 centers Least centersCars and c...
# 1           -1.0  Hotels are no longer limited to humans or anim...
# 2           -1.0  Within the framework of the ongoing cooperatio...
# 3           -1.0  GDP Saudi Arabia ranked 19th among the world's...
# 4           -1.0  1891 casesInfections CategoriesThe most outbre...
#
#
# File: ILR_CSVs/translated_arabic_news_articles_with_ilr10012024_part1.csv
#                                                title  \
# 0       إزالة وسائل الإعلام الروسية من فيسبوك وإخوته
# 1  موسكو... العقوبات الأمريكية ضد وسائل الإعلام ا...
# 2  الكرملين: سنرد على القيود الغربية على وسائل ال...
# 3  ميتا تحظر وسائل الإعلام الحكومية الروسية على م...
# 4  صحافة عربية تخلط بين "شركة الإخوان" الماليزية ...
#
#                                              summary  \
# 0  أعلنت الأميركية المالكة لتطبيقات فيسبوك وإنستغ...
# 1  وأفادت وكالة مهر للأنباء، انه قالت زاخاروفا في...
# 2  نقلت وكالة "تاس" للأنباء عن المتحدث باسم الكرم...
# 3  الفرنسية أعلنت مجموعة "ميتا" الأمريكية المالكة...
# 4  كوالالمبور- ذكرت هيئة تطوير الشؤون الإسلامية ف...
#
#                                                 text  \
# 0  أعلنت الأميركية المالكة لتطبيقات فيسبوك وإنستغ...
# 1  وأفادت وكالة مهر للأنباء، انه قالت زاخاروفا في...
# 2  نقلت وكالة "تاس" للأنباء عن المتحدث باسم الكرم...
# 3  الفرنسية أعلنت مجموعة "ميتا" الأمريكية المالكة...
# 4  كوالالمبور- ذكرت هيئة تطوير الشؤون الإسلامية ف...
#
#                                           translated  \
# 0  The American owner of the Facebook, Instagram ...
# 1  Mehr News Agency reported that Zakharova said ...
# 2  TASS news agency quoted Kremlin spokesman Dmit...
# 3  French\nThe American "Meta" group, which owns ...
# 4  Kuala Lumpur - The Islamic Affairs Development...
#
#                                                 link language  ilr_quantized  \
# 0  https://www.aljazeera.net/news/2024/9/17/%d9%8...   arabic            2.0
# 1  https://ar.mehrnews.com/news/1948492/%d9%85%d9...   arabic            2.0
# 2  https://www.alarabiya.net/arab-and-world/ameri...   arabic            2.0
# 3        https://gate.ahram.org.eg/news/4989511.aspx   arabic            2.5
# 4  https://www.aljazeera.net/politics/2024/9/15/%...   arabic            2.5
#
#                                   ilr_range  ilr_regressed  \
# 0   [1.9909156728081063, 2.015140545319823]       2.003028
# 1  [1.8612002136406007, 2.0832798718156393]       1.972240
# 2  [1.8694966428911501, 2.0783020142653097]       1.973899
# 3  [1.3252090518108295, 3.2048745689135023]       2.265042
# 4   [1.9021731016546175, 3.496378163908971]       2.699276
#
#                                   translated_summary
# 0  "تاس" "ترد بشكل مناسب" على القيود التي See mor...
# 1  "تاس" "ترد بشكل مناسب" على القيود التي See als...
# 2  "تاس" "ترد بشكل مناسب" على القيود التي See mor...
# 3  الفرنسية أعلنت مجموعة "ميتا" الأمريكية المالب ...
# 4  "جاكيم"، ال تي تستند في معاييرها إلى "مؤسسة ال...
#
#
# File: ILR_CSVs/translated_arabic_news_articles_with_ilr10012024_part2.csv
#                                                title  \
# 0  القومي للإعاقة يستمع للنساء ذوات الإعاقة ببرج ...
# 1  عراقجي: حوارات بناءة حول استقرار وأمن المنطقة ...
# 2  "ملفات نتنياهو": الفيلم الذي يكشف تفاصيل سرية ...
# 3  انتخابات تونس: هل عاد استقلال القضاء إلى نقطة ...
# 4  زاخاروفا: سنرد بحسم على العقوبات المفروضة على ...
#
#                                              summary  \
# 0  هايدي أيمن شاركت الدكتورة إيمان كريم، المشرف ا...
# 1  وأفادت وكالةمهر للأنباء، أن وزير الخارجية الإي...
# 2  عُرض الفيلم الوثائقي "ملفات بيبي" الليلة (الثل...
# 3  عاد الحديث بقوة في تونس، خلال الأسابيع القليلة...
# 4  موسكو-سانا أكدت المتحدثة الرسمية باسم وزارة ال...
#
#                                                 text  \
# 0  هايدي أيمن شاركت الدكتورة إيمان كريم، المشرف ا...
# 1  وأفادت وكالةمهر للأنباء، أن وزير الخارجية الإي...
# 2  عُرض الفيلم الوثائقي "ملفات بيبي" الليلة (الثل...
# 3  عاد الحديث بقوة في تونس، خلال الأسابيع القليلة...
# 4  موسكو-سانا أكدت المتحدثة الرسمية باسم وزارة ال...
#
#                                           translated  \
# 0  Heidi Ayman\nDr. Iman Karim, General Superviso...
# 1  Mehr News Agency reported that Iranian Foreign...
# 2  The documentary film "Bibi’s Files" was shown ...
# 3  There has been strong talk in Tunisia, over th...
# 4  Moscow-SANA\nRussian Foreign Ministry spokeswo...
#
#                                                 link language  ilr_quantized  \
# 0        https://gate.ahram.org.eg/news/4988960.aspx   arabic            2.5
# 1  https://ar.mehrnews.com/news/1948755/%d8%b9%d8...   arabic            2.5
# 2  https://www.i24news.tv/ar/%d8%a3%d8%ae%d8%a8%d...   arabic            2.0
# 3  https://www.aljazeera.net/opinions/2024/9/13/%...   arabic            3.5
# 4                         https://sana.sy/?p=2137133   arabic            2.0
#
#                                  ilr_range  ilr_regressed  \
# 0   [2.001459305001858, 2.799124416998885]       2.400292
# 1  [2.2237379650259674, 2.960436724956721]       2.592087
# 2  [1.1269787653800594, 2.523812740771964]       1.825396
# 3  [2.2959838862843887, 4.222409668229367]       3.259197
# 4   [1.566507486679271, 2.260095507992437]       1.913301
#
#                                   translated_summary
# 0  Heidi Ayman Dr. Iman Karim, General Supervisor...
# 1  Mehr News Agency reported that Iranian Foreign...
# 2  The documentary "The Baby Files" was screened ...
# 3  In Tunisia, talk has returned strongly in the ...
# 4  Moscow-SANA-Russian Foreign Ministry Spokesper...
#
#
#
# --- CHINESE ARTICLES ---
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part1.csv
#                               title  \
# 0  魔羯颱風狂掃東南亞...緬甸逾20萬民眾被迫搬家 軍政府罕見求援
# 1              俄前防長紹伊古會金正恩 強調永久雙邊關係
# 2               朝鲜76年国庆 与北京关系降温得到证实
# 3                    南韓媒：金正恩稱陸為「宿敵」
# 4         北韓不演了！金正恩再批中方「宿敵」 這大場面0出席
#
#                                              summary  \
# 0  颱風摩羯日前侵襲東南亞，緬甸軍政府領導人今天罕見請求外國協助因應致命洪水。這場洪災導致緬甸數...
# 1  俄羅斯前防長、現任聯邦安全會議秘書紹伊古（Sergei Shoigu）週五（13）訪問北韓平...
# 2  朝鲜今天周一庆祝建国 76 周年，放烟花，向朝鲜领导人金正恩的祖父金日成和父亲金正日致敬，但...
# 3  南韓中央日報廿日獨家報導，北韓國家領導人金正恩據稱將中國大陸定為「宿敵」。 據報導，大陸與北...
# 4  北韓領導人金正恩去（2023）年訪問俄羅斯會見俄國總統普丁，普丁今年6月回訪平壤並與北韓簽署...
#
#                                                 text  \
# 0  颱風摩羯日前侵襲東南亞，緬甸軍政府領導人今天罕見請求外國協助因應致命洪水。這場洪災導致緬甸數...
# 1  俄羅斯前防長、現任聯邦安全會議秘書紹伊古（Sergei Shoigu）週五（13）訪問北韓平...
# 2  朝鲜今天周一庆祝建国 76 周年，放烟花，向朝鲜领导人金正恩的祖父金日成和父亲金正日致敬，但...
# 3  南韓中央日報廿日獨家報導，北韓國家領導人金正恩據稱將中國大陸定為「宿敵」。 據報導，大陸與北...
# 4  北韓領導人金正恩去（2023）年訪問俄羅斯會見俄國總統普丁，普丁今年6月回訪平壤並與北韓簽署...
#
#                                   translated_summary  \
# 0  Myanmar's military leaders today made a rare r...
# 1  Former Russian Defense Minister and current Se...
# 2  North Korea celebrated its 76th anniversary to...
# 3  South Korea's JoongAng Ilbo exclusively report...
# 4  North Korean leader Kim Jong-un visited Russia...
#
#                                                 link language ilr_quantized  \
# 0            https://udn.com/news/story/6812/8228279  chinese             2
# 1  https://www.chinatimes.com/realtimenews/202409...  chinese           2.5
# 2  https://www.rfi.fr/cn/%e4%b8%ad%e5%9b%bd/20240...  chinese             2
# 3  https://udn.com/news/story/7331/8242820?from=u...  chinese           2.5
# 4  https://www.chinatimes.com/realtimenews/202409...  chinese             3
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0  [1.6513163451735977, 2.5811394247106705]  2.11622788494213        NaN  ...
# 1  [2.1242666903330587, 2.7254399858001648]  2.42485333806661        NaN  ...
# 2   [1.454795507846427, 2.9086741535892884]  2.18173483071786        NaN  ...
# 3   [1.6085682500974485, 3.034859049941531]  2.32171365001949        NaN  ...
# 4  [1.7678346143738395, 3.7392992313756963]  2.75356692287477        NaN  ...
#
#    Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 28  Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part2.csv
#                                    title  \
# 0                        联播观察｜北京开启'中非时刻'
# 1  中非合作论坛丨习近平出席中非合作论坛北京峰会开幕式并发表主旨讲话 _光明网
# 2               霍守業：威權衝擊國際秩序 遠大於建構嚇阻能力成本
# 3                      习近平向第十一届北京香山论坛致贺信
# 4               中非合作論壇 習近平：中非提升至全天候命運共同體
#
#                                              summary  \
# 0  2 4JIZBolRYdK world.huanqiu.com article 联播观察｜北...
# 1  新华社北京9月5日电（记者杨依军、孙奕）9月5日上午，国家主席习近平在北京人民大会堂出席中非...
# 2  （中央社記者游凱翔、廖文綺台北12日電）國防院今天舉辦台北安全對話，國防院董事長、一級上將霍...
# 3  新华报业网 > 首页 > 正文 习近平向第十一届北京香山论坛致贺信 新华社北京9月13日电 ...
# 4  中非合作論壇北京峰會4日至6日召開，開幕式於5日上午在北京人民大會堂舉行。大陸國家主席習近平...
#
#                                                 text  \
# 0  2 4JIZBolRYdK world.huanqiu.com article 联播观察｜北...
# 1  新华社北京9月5日电（记者杨依军、孙奕）9月5日上午，国家主席习近平在北京人民大会堂出席中非...
# 2  （中央社記者游凱翔、廖文綺台北12日電）國防院今天舉辦台北安全對話，國防院董事長、一級上將霍...
# 3  新华报业网 > 首页 > 正文 习近平向第十一届北京香山论坛致贺信 新华社北京9月13日电 ...
# 4  中非合作論壇北京峰會4日至6日召開，開幕式於5日上午在北京人民大會堂舉行。大陸國家主席習近平...
#
#                                   translated_summary  \
# 0  2 4JIZBolRYdK world.huanqiu.com article News B...
# 1                                                NaN
# 2  (Central News Agency reporters You Kai-hsiang ...
# 3  Xinhua News Network > Home > Text Xi Jinping s...
# 4  The Beijing Summit of the Forum on China-Afric...
#
#                                                 link language ilr_quantized  \
# 0      https://world.huanqiu.com/article/4jizbolrydk  chinese             3
# 1  https://politics.gmw.cn/2024-09/05/content_375...  chinese             3
# 2  https://www.cna.com.tw/news/aipl/202409120048....  chinese           3.5
# 3  https://www.xhby.net/content/s66e3af72e4b0458d...  chinese             2
# 4            https://udn.com/news/story/7331/8207893  chinese             2
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0  [1.9526382805328808, 3.6284170316802715]  2.79052765610658        NaN  ...
# 1   [2.9625556685272727, 3.062407219121212]  3.01248144382424        NaN  ...
# 2   [2.4329513950073647, 4.140229162995581]  3.28659027900147        NaN  ...
# 3  [1.9733121259618542, 2.0444797900635763]  2.00889595801272        NaN  ...
# 4   [1.913688079326164, 2.0517871524043017]  1.98273761586523        NaN  ...
#
#    Unnamed: 23 Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  \
# 0          NaN         NaN          NaN          NaN          NaN
# 1          NaN         NaN          NaN          NaN          NaN
# 2          NaN         NaN          NaN          NaN          NaN
# 3          NaN         NaN          NaN          NaN          NaN
# 4          NaN         NaN          NaN          NaN          NaN
#
#    Unnamed: 28  Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part3.csv
#                                title  \
# 0       时政新闻眼丨三中全会后首次考察，习近平来到这两座西部名城
# 1  非洲媒体：非中合作新举措将推动非中携手迈向现代化_中非_峰会_经济
# 2        零关税待遇 zero-tariff treatment
# 3                向非洲提供三千六百亿 习近平用意何在？
# 4         中非新時代 習近平：中非將掀起「全球南方」現代化熱潮
#
#                                              summary  \
# 0  初秋时节，岁物丰成。中非合作论坛北京峰会刚刚落下帷幕，习近平总书记就开启了国内考察行程。 9...
# 1  2024-09-14 08:34 来源: 人民网 发布于： 北京市 9月4日至6日，2024...
# 2  根据国务院关税税则委员会发布的公告，为扩大对最不发达国家单边开放，实现共同发展，自2024年...
# 3  第九届中非合作论坛北京峰会正在举行。中国国家主席习近平周四（9月5日）宣布，将在未来三年向非...
# 4  2024年中非合作論壇北京峰會5日在人民大會堂開幕。中國國家主席習近平出席開幕式並發表題為《...
#
#                                                 text  \
# 0  初秋时节，岁物丰成。中非合作论坛北京峰会刚刚落下帷幕，习近平总书记就开启了国内考察行程。 9...
# 1  2024-09-14 08:34 来源: 人民网 发布于： 北京市 9月4日至6日，2024...
# 2  根据国务院关税税则委员会发布的公告，为扩大对最不发达国家单边开放，实现共同发展，自2024年...
# 3  第九届中非合作论坛北京峰会正在举行。中国国家主席习近平周四（9月5日）宣布，将在未来三年向非...
# 4  2024年中非合作論壇北京峰會5日在人民大會堂開幕。中國國家主席習近平出席開幕式並發表題為《...
#
#                                   translated_summary  \
# 0  In early autumn, the harvest is abundant. The ...
# 1  2024-09-14 08:34 Source: People's Daily Online...
# 2  China will give all the least developed countr...
# 3  The 9th Forum on China-Africa Cooperation Beij...
# 4  The 2024 Beijing Summit of the Forum on China-...
#
#                                                 link language ilr_quantized  \
# 0  https://china.chinadaily.com.cn/a/202409/13/ws...  chinese             3
# 1            https://www.sohu.com/a/808882505_114731  chinese           2.5
# 2  http://cn.chinadaily.com.cn/a/202409/19/ws66eb...  chinese           2.5
# 3  https://www.rfa.org/mandarin/yataibaodao/junsh...  chinese           3.5
# 4  https://www.chinatimes.com/realtimenews/202409...  chinese             2
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0   [2.905618316887228, 3.1573028051879533]  3.03146056103759        NaN  ...
# 1    [2.482163984253418, 2.510701609447949]  2.49643279685068        NaN  ...
# 2  [2.2101319746670356, 2.6739208151997786]  2.44202639493341        NaN  ...
# 3    [2.455230668171623, 4.126861599097026]  3.29104613363432        NaN  ...
# 4  [1.6825235312234668, 2.5291274479608887]  2.10582548959218        NaN  ...
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part4.csv
#                               title  \
# 0                时政微观察丨中非一家亲 共享发展成果
# 1              台湾行政院长拟对中国公民非法入境加强打击
# 2  '行进中国'调研行｜向'新'而行，'疆'更美好_新疆_口岸_通关
# 3                        北京中轴线桥梁展举办
# 4           唱响'投资中国'和'中国投资'好声音 _光明网
#
#                                              summary  \
# 0  2 4JGxp63G8HC world.huanqiu.com article 时政微观察丨...
# 1  法新社报道，台湾行政院长9月16日表示，台湾政府将检查多起中国公民乘船非法进入台湾的案件，并...
# 2  在'行'中，看见'进'的中国。今年5月，人民网启动'行进中国'大型融媒体系列调研行，340名...
# 3  中新网北京新闻9月23日电 '凭桥周览'北京中轴线桥梁展览首次在北京市西城区泰安里文化艺术中...
# 4  图为第二十四届中国国际投资贸易洽谈会中心展馆。新华社记者 魏培全摄 9月8日至11日，第二十...
#
#                                                 text  \
# 0  2 4JGxp63G8HC world.huanqiu.com article 时政微观察丨...
# 1  法新社报道，台湾行政院长9月16日表示，台湾政府将检查多起中国公民乘船非法进入台湾的案件，并...
# 2  在'行'中，看见'进'的中国。今年5月，人民网启动'行进中国'大型融媒体系列调研行，340名...
# 3  中新网北京新闻9月23日电 '凭桥周览'北京中轴线桥梁展览首次在北京市西城区泰安里文化艺术中...
# 4  图为第二十四届中国国际投资贸易洽谈会中心展馆。新华社记者 魏培全摄 9月8日至11日，第二十...
#
#                                   translated_summary  \
# 0  2 4JGxp63G8HC world.huanqiu.com article Curren...
# 1  Agence France-Presse reported that Taiwan's Ex...
# 2  In the "travel", see the "progress" of China. ...
# 3  China News Service Beijing News, September 23 ...
# 4  The picture shows the central exhibition hall ...
#
#                                                 link language ilr_quantized  \
# 0      https://world.huanqiu.com/article/4jgxp63g8hc  chinese             3
# 1  https://www.rfi.fr/cn/%e5%8f%b0%e6%b9%be/20240...  chinese           2.5
# 2            https://www.sohu.com/a/807688617_114731  chinese           2.5
# 3  http://www.bj.chinanews.com.cn/news/2024/0923/...  chinese           2.5
# 4  https://economy.gmw.cn/2024-09/12/content_3755...  chinese           2.5
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0    [2.332287719449539, 4.112853800917435]  3.22257076018349        NaN  ...
# 1  [2.0419981359700046, 2.7748011184179973]    2.408399627194        NaN  ...
# 2   [1.298669271264714, 3.2207984372411715]  2.25973385425294        NaN  ...
# 3   [1.954431460891044, 2.8273411234653736]  2.39088629217821        NaN  ...
# 4   [1.8102081406318007, 3.649653098946999]   2.7299306197894        NaN  ...
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 29 Unnamed: 30  Unnamed: 31 Unnamed: 32
# 0         NaN         NaN          NaN         NaN
# 1         NaN         NaN          NaN         NaN
# 2         NaN         NaN          NaN         NaN
# 3         NaN         NaN          NaN         NaN
# 4         NaN         NaN          NaN         NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part5.csv
#                                    title  \
# 0                      第九次全国青年作家创作会议在京闭幕
# 1  '中国将接管西伯利亚和远东'谣言在俄流传，我大使回应_中俄关系_合作_发展
# 2       六部委联合表彰'全国对口支援西藏先进个人'_新闻频道_中国青年网
# 3                    新聞透視》台海少一點挑釁 換多一點和平
# 4            习近平文化思想对外翻译传播高端学术研讨会在浙江大学召开
#
#                                              summary  \
# 0  新华社北京9月3日电 9月3日下午，第九次全国青年作家创作会议在京闭幕。中共中央政治局委员、...
# 1  观察者网消息，据中国驻俄罗斯大使网站消息，9月11日，张汉晖大使就中俄高层交往、经贸合作、人...
# 2  六部委联合表彰'全国对口支援西藏先进个人' 发稿时间：2024-09-22 06:38:00...
# 3  美國在台協會前理事主席卜睿哲近日撰文分析美台安全夥伴關係，可說是從美國的國家利益角度，對台灣...
# 4  人民网讯 9月21日，'习近平文化思想对外翻译传播高端学术研讨会'在浙江大学召开。研讨会由中...
#
#                                                 text  \
# 0  新华社北京9月3日电 9月3日下午，第九次全国青年作家创作会议在京闭幕。中共中央政治局委员、...
# 1  观察者网消息，据中国驻俄罗斯大使网站消息，9月11日，张汉晖大使就中俄高层交往、经贸合作、人...
# 2  六部委联合表彰'全国对口支援西藏先进个人' 发稿时间：2024-09-22 06:38:00...
# 3  美國在台協會前理事主席卜睿哲近日撰文分析美台安全夥伴關係，可說是從美國的國家利益角度，對台灣...
# 4  人民网讯 9月21日，'习近平文化思想对外翻译传播高端学术研讨会'在浙江大学召开。研讨会由中...
#
#                                   translated_summary  \
# 0  Xinhua News Agency, Beijing, September 3rd. On...
# 1  According to the website of the Chinese Ambass...
# 2  Six ministries and commissions jointly commend...
# 3  Recently, Richard Bush, former chairman of the...
# 4  People's Daily Online: On September 21, the "H...
#
#                                                 link language ilr_quantized  \
# 0  http://politics.people.com.cn/n1/2024/0904/c10...  chinese             2
# 1         https://www.sohu.com/a/808281770_120388781  chinese           2.5
# 2  https://news.youth.cn/gn/202409/t20240922_1553...  chinese           2.5
# 3  https://www.chinatimes.com/newspapers/20240918...  chinese             3
# 4  http://world.people.com.cn/n1/2024/0922/c1002-...  chinese           2.5
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0  [1.6927602897530392, 2.5120661837449347]  2.10241323674899        NaN  ...
# 1  [1.9159336798206255, 3.4734438669656242]  2.69468877339313        NaN  ...
# 2   [1.8584947420467302, 2.884903154771962]  2.37169894840935        NaN  ...
# 3    [2.9862867719534165, 3.00822793682795]  2.99725735439068        NaN  ...
# 4  [2.1356891479021556, 2.7185865112587067]  2.42713782958043        NaN  ...
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN          NaN         NaN
# 1         NaN         NaN         NaN         NaN          NaN         NaN
# 2         NaN         NaN         NaN         NaN          NaN         NaN
# 3         NaN         NaN         NaN         NaN          NaN         NaN
# 4         NaN         NaN         NaN         NaN          NaN         NaN
#
#    Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part6.csv
#                                             title  \
# 0                                   习近平会见卢旺达总统卡加梅
# 1  中非合作论坛丨共叙友情 共商合作 共话未来——非洲多国人士瞩望中非合作论坛北京峰会 _光明网
# 2                            中菲就仙宾礁问题进行磋商 仍坚持各自立场
# 3                中国发布丨国家医保局：20省份和新疆生产建设兵团辅助生殖纳入医保
# 4                        金融時報：台美合作強化無人機供應鏈 排除仰賴中國
#
#                                              summary  \
# 0  9月5日晚，国家主席习近平在北京人民大会堂会见来华出席中非合作论坛北京峰会的卢旺达总统卡加梅...
# 1  新华社北京/阿比让9月3日电 题：共叙友情 共商合作 共话未来——非洲多国人士瞩望中非合作论...
# 2  （北京／马尼拉综合讯）中国和菲律宾在南中国海水域争端持续延烧之际，两国就仙宾礁（菲国称萨比纳...
# 3  中国网9月10日讯（记者 彭瑶） 党的二十届三中全会明确，完善生育支持政策体系和激励机制，推...
# 4  英國「金融時報」（The Financial Times）今天報導，台灣和美國正規畫開啟雙方...
#
#                                                 text  \
# 0  9月5日晚，国家主席习近平在北京人民大会堂会见来华出席中非合作论坛北京峰会的卢旺达总统卡加梅...
# 1  新华社北京/阿比让9月3日电 题：共叙友情 共商合作 共话未来——非洲多国人士瞩望中非合作论...
# 2  （北京／马尼拉综合讯）中国和菲律宾在南中国海水域争端持续延烧之际，两国就仙宾礁（菲国称萨比纳...
# 3  中国网9月10日讯（记者 彭瑶） 党的二十届三中全会明确，完善生育支持政策体系和激励机制，推...
# 4  英國「金融時報」（The Financial Times）今天報導，台灣和美國正規畫開啟雙方...
#
#                                   translated_summary  \
# 0                                                NaN
# 1  Xinhua News Agency Beijing/Abidjan, September ...
# 2  (Beijing/Manila Comprehensive News) As the dis...
# 3  China.com, September 10 (Reporter Peng Yao) Th...
# 4  The Financial Times reported today that Taiwan...
#
#                                                 link language ilr_quantized  \
# 0             https://www.whb.cn/commondetail/947100  chinese           2.5
# 1  https://politics.gmw.cn/2024-09/04/content_375...  chinese           2.5
# 2  https://www.zaobao.com.sg/news/china/story2024...  chinese             2
# 3  http://news.china.com.cn/2024-09/10/content_11...  chinese             3
# 4  https://udn.com/news/story/10930/8241317?list_...  chinese             2
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0     [1.568791935781917, 3.05872483853085]  2.31375838715638        NaN  ...
# 1  [1.7778431483215513, 3.7035947527974145]  2.74071895055948        NaN  ...
# 2    [1.838376844589618, 2.096973893246229]  1.96767536891792        NaN  ...
# 3  [1.8760979736989043, 3.6743412157806574]  2.77521959473978        NaN  ...
# 4   [1.4652833812960466, 2.891194364506589]  2.17823887290132        NaN  ...
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part7.csv
#                             title  \
# 0          几十年的不解之缘——习近平总书记和陕西的故事
# 1      习近平宣布未来三年向非洲提供3600亿人民币资金支持
# 2              立德树人｜以教育之强夯实国家富强之基
# 3                     俄罗斯总统普京会见王毅
# 4  学习·知行｜田间地头话农耕 习近平心系'中国饭碗'-国内国际
#
#                                              summary  \
# 0  【学习进行时】10日下午至11日上午，习近平总书记先后来到陕西省宝鸡市和甘肃省天水市考察调研...
# 1  中国国家主席习近平宣布，未来三年将向非洲提供3600亿元（人民币，下同，661亿新元）额度的...
# 2  教育兴则国家兴，教育强则国家强。党的十八大以来，习近平总书记多次强调发展教育的重要意义，为教...
# 3  新华社圣彼得堡9月12日电（记者安晓萌）12日，俄罗斯总统普京在圣彼得堡会见中共中央政治局委...
# 4  1、本网所载的文/图等稿件均出于为公众传播有益资讯信息之目的，并不意味着赞同其观点或证实其内...
#
#                                                 text  \
# 0  【学习进行时】10日下午至11日上午，习近平总书记先后来到陕西省宝鸡市和甘肃省天水市考察调研...
# 1  中国国家主席习近平宣布，未来三年将向非洲提供3600亿元（人民币，下同，661亿新元）额度的...
# 2  教育兴则国家兴，教育强则国家强。党的十八大以来，习近平总书记多次强调发展教育的重要意义，为教...
# 3  新华社圣彼得堡9月12日电（记者安晓萌）12日，俄罗斯总统普京在圣彼得堡会见中共中央政治局委...
# 4  1、本网所载的文/图等稿件均出于为公众传播有益资讯信息之目的，并不意味着赞同其观点或证实其内...
#
#                                   translated_summary  \
# 0  【Learning in Progress】 From the afternoon of t...
# 1  Chinese President Xi Jinping announced that Ch...
# 2  When education prospers, the country prospers;...
# 3  Xinhua News Agency, St. Petersburg, September ...
# 4  1. The texts/pictures and other manuscripts co...
#
#                                                 link language ilr_quantized  \
# 0           http://www.81.cn/xx_207779/16338470.html  chinese             3
# 1  https://www.zaobao.com.sg/realtime/china/story...  chinese             2
# 2  http://news.china.com.cn/2024-09/08/content_11...  chinese             2
# 3  https://www.shobserver.com/staticsg/res/html/w...  chinese             2
# 4  https://news.jxnews.com.cn/system/2024/09/23/0...  chinese           2.5
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0  [2.6417331259576144, 3.2149601244254313]  2.92834662519152        NaN  ...
# 1   [1.3018608857336744, 3.163565190443876]  2.23271303808878        NaN  ...
# 2   [1.8970006430180888, 2.171665594969852]  2.03433311899397        NaN  ...
# 3      [1.62845834788817, 2.61923608685305]  2.12384721737061        NaN  ...
# 4   [2.4433453079417973, 2.594424486763671]  2.51888489735273        NaN  ...
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part8.csv
#                                                title  \
# 0       奋进强国路 阔步新征程｜总量连上台阶 结构优化升级——新中国成立75周年经济发展成就综述
# 1  视频丨习近平在全国教育大会上发表重要讲话，代表党中央向全国广大教师和教育工作者致以节日祝贺和...
# 2                                  朝鲜外务省工作代表团对越南进行访问
# 3                            澳荷國會通過2758號決議不涉台 綠盼立院響應
# 4        中国农民丰收节丨礼赞丰收 天山南北'丰'景如画——写在第七个'中国农民丰收节'到来之际
#
#                                              summary  \
# 0  新华社北京9月8日电 题：总量连上台阶 结构优化升级——新中国成立75周年经济发展成就综述 ...
# 1  全国教育大会9日至10日在北京召开。中共中央总书记、国家主席、中央军委主席习近平出席大会并发...
# 2  越通社河内——9月9日下午，越南政府副总理兼外交部部长裴青山在外交部驻地会见了朝鲜外务省副相...
# 3  繼澳洲參議院之後，荷蘭國會昨天以147票對3票通過「拒絕中國扭曲聯合國大會第2758號決議」...
# 4  石榴云/新疆日报记者 魏永贵 金秋九月，叠翠流金，天山南北迎来丰收季。 95%的杂交玉米种子...
#
#                                                 text  \
# 0  新华社北京9月8日电 题：总量连上台阶 结构优化升级——新中国成立75周年经济发展成就综述 ...
# 1  全国教育大会9日至10日在北京召开。中共中央总书记、国家主席、中央军委主席习近平出席大会并发...
# 2  越通社河内——9月9日下午，越南政府副总理兼外交部部长裴青山在外交部驻地会见了朝鲜外务省副相...
# 3  繼澳洲參議院之後，荷蘭國會昨天以147票對3票通過「拒絕中國扭曲聯合國大會第2758號決議」...
# 4                       '百亩攻关、千亩创建、万亩示范'，全疆粮食大面积均衡增产
#
#                                   translated_summary  \
# 0  Xinhua News Agency, Beijing, September 8th. Ti...
# 1  The National Education Conference was held in ...
# 2  VNA Hanoi —— On the afternoon of September 9, ...
# 3  Following the Australian Senate, the Dutch Par...
# 4               预计棉籽产量640万吨，棉籽油产量60万吨，成为国家'油瓶子'重要供应源
#
#                                                 link  \
# 0  http://politics.people.com.cn/n1/2024/0908/c10...
# 1  https://www.thepaper.cn/newsdetail_forward_286...
# 2  https://zh.vietnamplus.vn/%e6%9c%9d%e9%b2%9c%e...
# 3            https://udn.com/news/story/6656/8226300
# 4                 林果、畜牧、渔业结构调整增长稳定，新疆'海鲜'成为全国消费者'新宠'
#
#                     language  \
# 0                    chinese
# 1                    chinese
# 2                    chinese
# 3                    chinese
# 4  一望无垠的整齐条田里，先进的智能化农机装备在...
#
#                                        ilr_quantized  \
# 0                                                  3
# 1                                                1.5
# 2                                                  2
# 3                                                2.5
# 4  石榴云/新疆日报记者 魏永贵 金秋九月，叠翠流金，天山南北迎来丰收季。 95%的杂交玉米种子...
#
#                                  ilr_range  \
# 0    [2.118379806508017, 3.52897211609519]
# 1  [0.7852179877694994, 2.691303353717501]
# 2  [1.707589017706539, 2.4873516371557685]
# 3  [1.9528834829006314, 2.828269910259621]
# 4             '百亩攻关、千亩创建、万亩示范'，全疆粮食大面积均衡增产
#
#                           ilr_regressed                          Unnamed: 9  \
# 0                       2.8236759613016                                 NaN
# 1                       1.7382606707435                                 NaN
# 2                      2.09747032743115                                 NaN
# 3                      2.39057669658013                                 NaN
# 4  预计棉籽产量640万吨，棉籽油产量60万吨，成为国家'油瓶子'重要供应源  林果、畜牧、渔业结构调整增长稳定，新疆'海鲜'成为全国消费者'新宠'
#
#    ... Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# 0  ...         NaN         NaN         NaN         NaN         NaN
# 1  ...         NaN         NaN         NaN         NaN         NaN
# 2  ...         NaN         NaN         NaN         NaN         NaN
# 3  ...         NaN         NaN         NaN         NaN         NaN
# 4  ...         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part9.csv
#                            title  \
# 0      德国恢复所有陆地边界管控措施 一度造成边境道路拥堵
# 1               北京中轴线地铁2号线专列上线运营
# 2        科技强国建设扎实推进（奋进强国路 阔步新征程）
# 3  外媒：Meta宣布禁止'今日俄罗斯'等俄媒使用旗下应用平台
# 4           让退役军人成为全社会尊重的人（金台点兵）
#
#                                              summary  \
# 0  4JTOXdckCQs world.huanqiu.com article 德国恢复所有陆地...
# 1  北京中轴线地铁2号线专列上线运营。北京地铁供图 北京中轴线地铁2号线专列上线运营。北京地铁供...
# 2  累计建成基站近400万个，5G移动电话用户达9.5亿户，建成全球规模最大、技术领先的5G网络...
# 3  4JTSMCPvuqw 作者：姜蔼玲 world.huanqiu.com article 外...
# 4  退役军人是党和国家的宝贵财富，是推进中国式现代化的重要力量，退役军人工作事关改革发展稳定和强...
#
#                                                 text  \
# 0  4JTOXdckCQs world.huanqiu.com article 德国恢复所有陆地...
# 1  北京中轴线地铁2号线专列上线运营。北京地铁供图 北京中轴线地铁2号线专列上线运营。北京地铁供...
# 2  累计建成基站近400万个，5G移动电话用户达9.5亿户，建成全球规模最大、技术领先的5G网络...
# 3  4JTSMCPvuqw 作者：姜蔼玲 world.huanqiu.com article 外...
# 4  退役军人是党和国家的宝贵财富，是推进中国式现代化的重要力量，退役军人工作事关改革发展稳定和强...
#
#                                   translated_summary  \
# 0  4JTOXdckCQs world.huanqiu.com article Germany ...
# 1  Beijing Central Axis Metro Line 2 special trai...
# 2  Nearly 4 million base stations have been built...
# 3  4JTSMCPvuqw Author: Jiang Ai Ling world.huanqi...
# 4  Veterans are the precious wealth of the Party ...
#
#                                                 link language ilr_quantized  \
# 0      https://world.huanqiu.com/article/4jtoxdckcqs  chinese             3
# 1  http://www.bj.chinanews.com.cn/news/2024/0908/...  chinese           2.5
# 2  http://politics.people.com.cn/n1/2024/0923/c10...  chinese             3
# 3      https://world.huanqiu.com/article/4jtsmcpvuqw  chinese             3
# 4  http://military.people.com.cn/n1/2024/0901/c10...  chinese           2.5
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0   [2.1940595075729448, 3.483564295456233]  2.83881190151459        NaN  ...
# 1     [2.074070008839442, 3.20988331860093]  2.64197666372019        NaN  ...
# 2   [2.9953678839441977, 3.007720193426337]  3.00154403868527        NaN  ...
# 3    [2.138328731947638, 3.517002760831417]  2.82766574638953        NaN  ...
# 4  [2.2263203325996415, 2.9561327790005976]  2.59122655580012        NaN  ...
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part10.csv
#                              title  \
# 0       世卫组织：黎巴嫩通信设备爆炸事件严重扰乱该国卫生系统
# 1             時論廣場》兩岸好 才有國際空間（李正修）
# 2      介文汲蕭旭岑指干預柯文哲案 AIT：不介入台灣司法事務
# 3                中国西部游受海外游客青睐_腾讯新闻
# 4  鉴往知来，跟着总书记学历史丨在'青铜史诗'里，触摸'中国'脉搏
#
#                                              summary  \
# 0  4JViafjebbf world.huanqiu.com article 世卫组织：黎巴嫩...
# 1  第79屆聯合國大會將於10日開議，賴政府定調今年推動聯合國案的首要任務，是駁斥聯大第2758...
# 2  （9/14 17:17 更新） （中央社記者吳書緯、溫貴香台北14日電）民眾黨主席柯文哲因京...
# 3  新华社成都9月2日电 题：中国西部游受海外游客青睐 新华社记者张超群 '来成都，我感受到美丽...
# 4  '古公亶父，来朝走马。率西水浒，至于岐下。' 3000多年前，周人跋山涉水，来到岐山脚下定居...
#
#                                                 text  \
# 0  4JViafjebbf world.huanqiu.com article 世卫组织：黎巴嫩...
# 1  第79屆聯合國大會將於10日開議，賴政府定調今年推動聯合國案的首要任務，是駁斥聯大第2758...
# 2  （9/14 17:17 更新） （中央社記者吳書緯、溫貴香台北14日電）民眾黨主席柯文哲因京...
# 3  新华社成都9月2日电 题：中国西部游受海外游客青睐 新华社记者张超群 '来成都，我感受到美丽...
# 4  因出土大量青铜器，宝鸡也成为享誉世界的'青铜器之乡'。 9月10日下午，习近平总书记考察了宝...
#
#                                   translated_summary  \
# 0  4JViafjebbf world.huanqiu.com article WHO: The...
# 1  The 79th UN General Assembly will open on the ...
# 2  (Updated at 17:17 on 9/14) (Central News Agenc...
# 3  Xinhua News Agency Chengdu, September 2. Quest...
# 4  '古公亶父，来朝走马。率西水浒，至于岐下。' 3000多年前，周人跋山涉水，来到岐山脚下定居...
#
#                                                 link  \
# 0      https://world.huanqiu.com/article/4jviafjebbf
# 1  https://www.chinatimes.com/opinion/20240904004...
# 2  https://www.cna.com.tw/news/aipl/202409140155....
# 3         https://new.qq.com/rain/a/20240902a01irh00
# 4  因出土大量青铜器，宝鸡也成为享誉世界的'青铜器之乡'。 9月10日下午，习近平总书记考察了宝...
#
#                                             language  \
# 0                                            chinese
# 1                                            chinese
# 2                                            chinese
# 3                                            chinese
# 4   极具历史价值的逨盘，内铸铭文21行372字，以第一人称记述了单氏家族8代人辅佐西周12代天...
#
#                                        ilr_quantized  \
# 0                                                  3
# 1                                                  3
# 2                                                2.5
# 3                                                2.5
# 4   …… 金文载史，煌煌春秋。一件件'重器'，铭文记录着数千年前的为政准则或国之大事，堪称一部...
#
#                                            ilr_range  \
# 0           [2.1842867038289455, 3.4894279777026327]
# 1            [2.870539163897263, 3.2157680601712286]
# 2            [2.308459930931292, 2.8192334484478465]
# 3            [2.480353397007036, 2.5327443383216064]
# 4  红色丝带飘逸飞舞、环绕向上，与火炬设计和谐统一。 这一刻，冬奥之火'邂逅'青铜之光，共同浇灌...
#
#                                        ilr_regressed  \
# 0                                   2.83685734076579
# 1                                   3.04315361203425
# 2                                   2.56384668968957
# 3                                   2.50654886766432
# 4  'Gu Gongdanfu, come and go. Lead the Western W...
#
#                                           Unnamed: 9  ... Unnamed: 23  \
# 0                                                NaN  ...         NaN
# 1                                                NaN  ...         NaN
# 2                                                NaN  ...         NaN
# 3                                                NaN  ...         NaN
# 4  http://xuexi.voc.com.cn/news/2024/09/12/570192...  ...         NaN
#
#   Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 30  Unnamed: 31 Unnamed: 32
# 0         NaN          NaN         NaN
# 1         NaN          NaN         NaN
# 2         NaN          NaN         NaN
# 3         NaN          NaN         NaN
# 4         NaN          NaN         NaN
#
# [5 rows x 33 columns]
#
#
# File: ILR_CSVs/chinese_news_articles_with_ilr20241119_part11.csv
#                              title  \
# 0               微软和贝莱德计划推出AI基础设施基金
# 1              罢工持续，波音航空航天业务双双'折翼'
# 2  外媒：墨西哥当选总统拒绝应邀访乌，称其'主要任务是管理墨西哥'
# 3           暑运旺季中国民航旅客运输量创新高 支线航空热
# 4   官媒抨擊網紅滋擾日本遊客「蹭流量」 評論：民族主義是中共專利
#
#                                              summary  \
# 0  4JUlRynabKc 作者：任重 world.huanqiu.com article 微软...
# 1  4JUlPumcDty 作者：甄翔 world.huanqiu.com article 罢工...
# 2  4JUPHZZ7NNf world.huanqiu.com article 外媒：墨西哥当选...
# 3  中新社北京9月3日电 (尹倩芸)2024年暑运(7月1日至8月31日)收官，多家航司发布暑运...
# 4  繼中國網紅「張教官」在巴黎長榮桂冠酒店以酒店沒掛上中國國旗造文章，成功博取流量後，上周六（7...
#
#                                                 text  \
# 0  4JUlRynabKc 作者：任重 world.huanqiu.com article 微软...
# 1  4JUlPumcDty 作者：甄翔 world.huanqiu.com article 罢工...
# 2  4JUPHZZ7NNf world.huanqiu.com article 外媒：墨西哥当选...
# 3  中新社北京9月3日电 (尹倩芸)2024年暑运(7月1日至8月31日)收官，多家航司发布暑运...
# 4  繼中國網紅「張教官」在巴黎長榮桂冠酒店以酒店沒掛上中國國旗造文章，成功博取流量後，上周六（7...
#
#                                   translated_summary  \
# 0  4JUlRynabKc Author: Ren Zhong world.huanqiu.co...
# 1  4JUlPumcDty Author: Zhen Xiang world.huanqiu.c...
# 2  4JUPHZZ7NNf world.huanqiu.com article Foreign ...
# 3  China News Service, Beijing, September 3 (Yin ...
# 4  After the Chinese social networking site "Chan...
#
#                                                 link language ilr_quantized  \
# 0      https://world.huanqiu.com/article/4julrynabkc  chinese             3
# 1      https://world.huanqiu.com/article/4julpumcdty  chinese             3
# 2      https://world.huanqiu.com/article/4juphzz7nnf  chinese             3
# 3  http://news.china.com.cn/2024-09/04/content_11...  chinese           1.5
# 4  https://www.rfa.org/cantonese/news/cn-influenc...  chinese             3
#
#                                   ilr_range     ilr_regressed Unnamed: 9  ...  \
# 0  [2.6903798032607824, 3.1857721180435306]  2.93807596065216        NaN  ...
# 1    [2.411143594735165, 3.353313843158901]  2.88222871894703        NaN  ...
# 2  [2.2808062952835257, 3.4315162228298846]  2.85616125905671        NaN  ...
# 3     [1.427187466706016, 1.62135422215664]  1.52427084443133        NaN  ...
# 4    [2.533928367498845, 3.279642979500693]  2.90678567349977        NaN  ...
#
#   Unnamed: 23 Unnamed: 24 Unnamed: 25  Unnamed: 26 Unnamed: 27  Unnamed: 28  \
# 0         NaN         NaN         NaN          NaN         NaN          NaN
# 1         NaN         NaN         NaN          NaN         NaN          NaN
# 2         NaN         NaN         NaN          NaN         NaN          NaN
# 3         NaN         NaN         NaN          NaN         NaN          NaN
# 4         NaN         NaN         NaN          NaN         NaN          NaN
#
#    Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 33 columns]
#
#
#
# --- ENGLISH ARTICLES ---
#
# File: ILR_CSVs/english_news_articles_with_ilr7182024_part1.csv
#                                                title  \
# 0                  The Assignment with Audie Cornish
# 1                  All There Is with Anderson Cooper
# 2                 Chasing Life with Dr. Sanjay Gupta
# 3                                  ABOUT CNN DIGITAL
# 4  #AsEquals: These are the challenges facing wom...
#
#                                              summary authors publish_date  \
# 0  Trump’s Close Call Re-Shapes the Race The Assi...     NaN          NaN
# 1  Sharing Our Grief All There Is with Anderson C...     NaN          NaN
# 2  The Habits of Happy People Chasing Life Have y...     NaN          NaN
# 3  CNN Digital is the world leader in online news...     NaN          NaN
# 4  As Equals is a CNN series that aims to reveal ...     NaN          NaN
#
#                                            top_image videos  \
# 0  https://www.cnn.com/audio/static/images/podcas...    NaN
# 1  https://www.cnn.com/audio/static/images/podcas...    NaN
# 2  https://www.cnn.com/audio/static/images/podcas...    NaN
# 3  https://cdn.cnn.com/cnn/.e/img/4.0/logos/cnn_l...    NaN
# 4  https://i.cdn.turner.com/cnn/.e/img/3.0/global...    NaN
#
#                                                 text language  \
# 0  Trump’s Close Call Re-Shapes the Race The Assi...  English
# 1  Sharing Our Grief All There Is with Anderson C...  English
# 2  The Habits of Happy People Chasing Life Have y...  English
# 3  CNN Digital is the world leader in online news...  English
# 4  As Equals is a CNN series that aims to reveal ...  English
#
#                                                 link  ilr_score  ilr_detail  \
# 0  https://edition.cnn.com/audio/podcasts/the-ass...        NaN         NaN
# 1  https://edition.cnn.com/audio/podcasts/all-the...        NaN         NaN
# 2  https://edition.cnn.com/audio/podcasts/chasing...        NaN         NaN
# 3                      https://edition.cnn.com/about        NaN         NaN
# 4       https://edition.cnn.com/interactive/asequals        NaN         NaN
#
#    ilr_quantized                                 ilr_range  ilr_regressed
# 0            3.0   [2.745984542900721, 3.1524092742595675]       2.949197
# 1            3.0  [2.7952400631004783, 3.3412665614992028]       3.068253
# 2            2.5  [1.9152035376467174, 3.4746607705888044]       2.694932
# 3            2.5   [2.359243919090779, 2.5844536485455327]       2.471849
# 4            1.5  [0.8672104093722472, 2.5546493177129213]       1.710930
#
#
#
# --- FRENCH ARTICLES ---
#
# Error loading ILR_CSVs/french_news_articles_with_ilr10012024_part1.csv: Error tokenizing data. C error: EOF inside string starting at row 1233
#
# File: ILR_CSVs/french_news_articles_with_ilr10012024_part2.csv
# ...
#
#                                   translated_summary
# 0  The Ukrainian capital was once again hit by a ...
# 1  Russian President Vladimir Putin said on Thurs...
# 2  Wrecked Ukrainian military vehicle, Kursk regi...
# 3  The war between Russia and Ukraine is now in i...
# 4  Blinken does not confirm that he authorized ky...
#
#
# Error loading ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part2.csv: Error tokenizing data. C error: EOF inside string starting at row 1386
#
# Error loading ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part3.csv: Error tokenizing data. C error: Expected 10 fields in line 6, saw 13
#
#
# Error loading ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part4.csv: Error tokenizing data. C error: EOF inside string starting at row 1501
#
# Error loading ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part5.csv: Error tokenizing data. C error: EOF inside string starting at row 1451
#
# File: ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part6.csv
#                                                                                                                                                    title  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...                         the world's fashionable DJ
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...  Si los partidos políticos europeos fueran marc...
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...  Madrid se encuentra en plena preparación para ...
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...  Por Sergio Rodríguez Gelfenstein, Resumen Lati...
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...  MADRID, 23 Sep. (EUROPA PRESS) - El presidente...
#
#                                                                                                                                                  summary  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...                                 queen of Instagram
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...  If European political parties were publicly tr...
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...  Madrid is in full preparation for an event tha...
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...  By Sergio Rodríguez Gelfenstein, Latin America...
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...  MADRID, Sep 23. (EUROPA PRESS) -\nThe presiden...
#
#                                                                                                                                                     text  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...   who closed the night with her mix of techno a...
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...  https://www.elperiodico.com/es/internacional/2...
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...  https://www.elconfidencial.com/television/euro...
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...  https://www.resumenlatinoamericano.org/2024/09...
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...  https://www.europapress.es/internacional/notic...
#
#                                                                                                                                             translated  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...   a tribute to the Ibizan sound of that decade."
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...                                          turkish
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...                                          turkish
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...                                          turkish
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...                                          turkish
#
#                                                                                                                                                     link  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...  https://www.elespanol.com/el-cultural/escenari...
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...                                                3.5
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...                                                2.0
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...                                                3.5
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...                                                2.5
#
#                                                                                                                                       language  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...                                  turkish
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...  [2.8973085151340037, 4.504485808109994]
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...  [1.8236471716079485, 2.293921380653419]
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...  [2.9451764613234026, 4.424705897794329]
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...  [1.3205832338329948, 3.207650059700203]
#
#                                                                                                        ilr_quantized  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...       2.500000
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...       3.700897
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...       2.058784
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...       3.684941
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...       2.264117
#
#                                                                                                                                                ilr_range  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...           [2.1674551109075857, 2.6995269334554486]
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...  If European political parties were publicly tr...
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...  Madrid is in the midst of preparations for an ...
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...  By Sergio Rodríguez Gelfenstein, Resumen Latin...
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...  MADRID, Sep 23 (EUROPA PRESS) - Iranian Presid...
#
#                                                                                                        ilr_regressed  \
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...       2.433491
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...            NaN
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...            NaN
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...            NaN
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...            NaN
#
#                                                                                                                                       translated_summary
# And to say goodbye to this first edition            the somewhat overrated South Korean electronic...  Now without rain (just a few drops) and with m...
# Combate a la ultraderecha: ¿sirven los cordones... Si los partidos políticos europeos fueran marca...                                                NaN
# Eurovisión Junior 2024: dónde se celebrará, fec... Madrid se encuentra en plena preparación para u...                                                NaN
# Internacional. BRICS: hacia la Cumbre de Kazán,... Por Sergio Rodríguez Gelfenstein, Resumen Latin...                                                NaN
# Pezeshkian asegura que Irán no quiere una guerr... MADRID, 23 Sep. (EUROPA PRESS) - El presidente ...                                                NaN
#
#
# File: ILR_CSVs/translated_spanish_news_articles_with_ilr10012024_part7.csv
#                                                title  \
# 0  ¿Vuelves de vacaciones? Estas son las noticias...
# 1                  Recordando la batalla de Carabobo
# 2  Venezuela se manifiesta ante las Cortes: "Me m...
# 3                        El PSOE gobierna con Meloni
# 4  Presidenta del Supremo mexicano se une a las p...
#
#                                              summary  \
# 0  madrid Actualizado: Público Volver a casa tras...
# 1  No pasa nada. Ayer, el Congreso aprobó reconoc...
# 2  "El 22 de junio del año 2017 mi hijo fue a una...
# 3  Disiento del fervor mayoritario hacia Teresa R...
# 4  Ciudad de México, 6 sep (EFE).- La ministra pr...
#
#                                                 text  \
# 0  madrid Actualizado: Público Volver a casa tras...
# 1  No pasa nada. Ayer, el Congreso aprobó reconoc...
# 2  "El 22 de junio del año 2017 mi hijo fue a una...
# 3  Disiento del fervor mayoritario hacia Teresa R...
# 4  Ciudad de México, 6 sep (EFE).- La ministra pr...
#
#                                           translated  \
# 0  madrid\nUpdated:\nPublic\nComing home from vac...
# 1  Nothing happens. Yesterday, Congress approved ...
# 2  "On June 22, 2017, my son went to a protest in...
# 3  I disagree with the majority fervor towards Te...
# 4  Mexico City, Sep 6 (EFE).- The minister presid...
#
#                                                 link language  ilr_quantized  \
# 0  https://www.publico.es/politica/vuelves-vacaci...  turkish            3.5
# 1  https://diariodeavisos.elespanol.com/2024/09/r...  turkish            3.0
# 2  https://www.elconfidencial.com/mundo/2024-09-1...  turkish            3.0
# 3  https://www.lne.es/opinion/2024/09/20/psoe-gob...  turkish            3.0
# 4  https://www.swissinfo.ch/spa/presidenta-del-su...  turkish            2.5
#
#                                   ilr_range  ilr_regressed  \
# 0    [2.847566976437438, 3.891459814137537]       3.369513
# 1     [2.670576826188384, 3.54903862301936]       3.109808
# 2   [2.641073196690062, 3.5982113388498966]       3.119642
# 3  [2.9371189005753457, 3.1048018323744238]       3.020960
# 4   [1.8683888827198736, 2.878966670368076]       2.373678
#
#                                   translated_summary
# 0  madrid Updated: Public Coming home after the h...
# 1  Nothing happens. Yesterday, Congress approved ...
# 2  "On June 22, 2017, my son went to a protest in...
# 3  I disagree with the majority's fervor towards ...
# 4  Mexico City, Sep 6 (EFE).- The presiding judge...
#
#
#
# --- TURKISH ARTICLES ---
#
# Error loading ILR_CSVs/turkish_news_part1_part1.csv: Error tokenizing data. C error: EOF inside string starting at row 1706
#
# File: ILR_CSVs/turkish_news_part1_part2.csv
#                                                title  \
# 0  I have once again stressed Turkey's strong sup...
# 1        The breath of our state is in their hands""
# 2  Erdogan said that they have confirmed the will...
# 3  I have communicated to Mr. Prime Minister that...
# 4           Stating that they also discussed current
#
#                                              summary  \
# 0                                        sovereignty
# 1                                                NaN
# 2                                            adding:
# 3                                              ports
# 4   regional and global issues during their talks...
#
#                                                 text  \
# 0   stability and prosperity. I also said that Ge...
# 1                                                NaN
# 2                                                NaN
# 3                                              roads
# 4   Erdogan said they shared assessments about th...
#
#                                   translated_summary  \
# 0   we hope and desire that the developments will...
# 1                                                NaN
# 2                                                NaN
# 3   renewable energy production and transport. In...
# 4                                                NaN
#
#                                                 link  \
# 0   we focused on 5 billion dollars as the new ta...
# 1                                                NaN
# 2                                                NaN
# 3   we also reviewed our relations in the field o...
# 4                                                NaN
#
#                                             language  \
# 0   who pointed out that a significant column of ...
# 1                                                NaN
# 2                                                NaN
# 3   especially FETO and PKK. We are determined to...
# 4                                                NaN
#
#                                        ilr_quantized  \
# 0   ""We are continuing our efforts to restore th...
# 1                                                NaN
# 2                                                NaN
# 3   which means the peace and even life of our ci...
# 4                                                NaN
#
#                               ilr_range  \
# 0   the backbone of the Middle Corridor
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                                        ilr_regressed  \
# 0   which brought the historical Silk Road to lif...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                          Unnamed: 9  Unnamed: 10
# 0   to its full capacity"" he said.          NaN
# 1                               NaN          NaN
# 2                               NaN          NaN
# 3                               NaN          NaN
# 4                               NaN          NaN
#
#
# Results saved to aggregated_results.csv

# %%
# List of French CSV files to parse

french_csv_files = [

    "ILR_CSVs/french_news_articles_with_ilr10012024_part1.csv",

    "ILR_CSVs/french_news_articles_with_ilr10012024_part2.csv",

    "ILR_CSVs/french_news_articles_with_ilr10012024_part3.csv",

    "ILR_CSVs/french_news_articles_with_ilr10012024_part4.csv",

    "ILR_CSVs/french_news_articles_with_ilr10012024_part5.csv",

    "ILR_CSVs/french_news_articles_with_ilr10012024_part6.csv",

    "ILR_CSVs/french_news_articles_with_ilr10012024_part7.csv",

    "ILR_CSVs/translated_french_news7192024_part1.csv"

]



# Dictionary to store column names for each file

french_columns = {}



# Parse each file and store the column names

for file_path in french_csv_files:

    try:

        df = pd.read_csv(file_path, nrows=0)  # Read only the header for efficiency

        french_columns[file_path] = df.columns.tolist()

    except Exception as e:

        french_columns[file_path] = f"Error: {e}"



french_columns
# Out:
# {'ILR_CSVs/french_news_articles_with_ilr10012024_part1.csv': ['title',
#   'summary',
#   'text',
#   'translated',
#   'link',
#   'french',
#   'Unnamed: 6',
#   'ilr_quantized',
#   'ilr_range',
#   'ilr_regressed'],
#  'ILR_CSVs/french_news_articles_with_ilr10012024_part2.csv': ['title',
#   'summary',
#   'text',
#   'translated',
#   'link',
#   'french',
#   'Unnamed: 6',
#   'ilr_quantized',
#   'ilr_range',
#   'ilr_regressed'],
#  'ILR_CSVs/french_news_articles_with_ilr10012024_part3.csv': ['title',
#   'summary',
#   'text',
#   'translated',
#   'link',
#   'french',
#   'Unnamed: 6',
#   'ilr_quantized',
#   'ilr_range',
#   'ilr_regressed'],
#  'ILR_CSVs/french_news_articles_with_ilr10012024_part4.csv': ['title',
#   'summary',
#   'text',
#   'translated',
#   'link',
#   'french',
#   'Unnamed: 6',
#   'ilr_quantized',
#   'ilr_range',
#   'ilr_regressed'],
#  'ILR_CSVs/french_news_articles_with_ilr10012024_part5.csv': ['title',
#   'summary',
#   'text',
#   'translated',
#   'link',
#   'french',
#   'Unnamed: 6',
#   'ilr_quantized',
#   'ilr_range',
#   'ilr_regressed'],
#  'ILR_CSVs/french_news_articles_with_ilr10012024_part6.csv': ['title',
#   'summary',
#   'text',
#   'translated',
#   'link',
#   'french',
#   'Unnamed: 6',
#   'ilr_quantized',
#   'ilr_range',
#   'ilr_regressed'],
#  'ILR_CSVs/french_news_articles_with_ilr10012024_part7.csv': ['title',
#   'summary',
#   'text',
#   'translated',
#   'link',
#   'french',
#   'Unnamed: 6',
#   'ilr_quantized',
#   'ilr_range',
#   'ilr_regressed'],
#  'ILR_CSVs/translated_french_news7192024_part1.csv': ['title',
#   'summary',
#   'text',
#   'language',
#   'link',
#   'ilr_quantized',
#   'ilr_range',
#   'ilr_regressed',
#   'translated_summary']}

# %%
import pandas as pd

# List of French CSV files
french_csv_files = [
    "ILR_CSVs/french_news_articles_with_ilr10012024_part1.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part2.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part3.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part4.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part5.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part6.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part7.csv",
    "ILR_CSVs/translated_french_news7192024_part1.csv"
]

# Process each file
for file_path in french_csv_files:
    try:
        # Load the CSV
        df = pd.read_csv(file_path)
        
        # Rename the column if it exists
        if "translated" in df.columns:
            df.rename(columns={"translated": "translated_summary"}, inplace=True)
            print(f"Renamed 'translated' to 'translated_summary' in {file_path}")
        
        # Save back to the same file (or a new file if needed)
        df.to_csv(file_path, index=False)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
# Out:
# Error processing ILR_CSVs/french_news_articles_with_ilr10012024_part1.csv: Error tokenizing data. C error: EOF inside string starting at row 1233
# Renamed 'translated' to 'translated_summary' in ILR_CSVs/french_news_articles_with_ilr10012024_part2.csv
# Renamed 'translated' to 'translated_summary' in ILR_CSVs/french_news_articles_with_ilr10012024_part3.csv
# Renamed 'translated' to 'translated_summary' in ILR_CSVs/french_news_articles_with_ilr10012024_part4.csv
# Renamed 'translated' to 'translated_summary' in ILR_CSVs/french_news_articles_with_ilr10012024_part5.csv
# Renamed 'translated' to 'translated_summary' in ILR_CSVs/french_news_articles_with_ilr10012024_part6.csv
# Renamed 'translated' to 'translated_summary' in ILR_CSVs/french_news_articles_with_ilr10012024_part7.csv

# %%
import pandas as pd

# List of French CSV files
french_csv_files = [
    "ILR_CSVs/french_news_articles_with_ilr10012024_part1.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part2.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part3.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part4.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part5.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part6.csv",
    "ILR_CSVs/french_news_articles_with_ilr10012024_part7.csv",
    "ILR_CSVs/translated_french_news7192024_part1.csv"
]

# Process each file
for file_path in french_csv_files:
    try:
        # Load the CSV
        df = pd.read_csv(file_path)
        
        # Rename the column if it exists
        if "translated" in df.columns:
            df.rename(columns={"translated": "translated_summary"}, inplace=True)
            print(f"Renamed 'translated' to 'translated_summary' in {file_path}")
        
        # Save back to the same file (or a new file if needed)
        df.to_csv(file_path, index=False)
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
# Out:
# Error processing ILR_CSVs/french_news_articles_with_ilr10012024_part1.csv: Error tokenizing data. C error: EOF inside string starting at row 1233
